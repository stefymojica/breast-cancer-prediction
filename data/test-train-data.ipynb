# %%
import pandas as pd
import copy

pd.set_option('display.max_columns', None)
url = 'https://demo-breast-cancer-prediction.s3.us-east-2.amazonaws.com/data.csv'
df_train = pd.read_csv(url)

# %%
df_train
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0      842302         M        17.99         10.38          122.80     1001.0  \
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df_test = copy.deepcopy(df_train)

# %%
df_test = df_test.tail(68)

# %%
df_test.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 501   91504         M       13.820         24.49           92.33      595.9  \
# 502   91505         B       12.540         16.32           81.25      476.3
# 503  915143         M       23.090         19.83          152.10     1682.0
# 504  915186         B        9.268         12.87           61.49      248.7
# 505  915276         B        9.676         13.14           64.12      272.5
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 501          0.11620            0.1681         0.13570              0.06759  \
# 502          0.11580            0.1085         0.05928              0.03279
# 503          0.09342            0.1275         0.16760              0.10030
# 504          0.16340            0.2239         0.09730              0.05252
# 505          0.12550            0.2204         0.11880              0.07038
#
# ...

# %%
df_train = df_train.iloc[:-68,:]

# %%
df_train
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0      842302         M        17.99         10.38          122.80     1001.0  \
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 496    914366         B        12.65         18.17           82.69      485.6
# 497    914580         B        12.47         17.31           80.45      480.1
# 498    914769         M        18.49         17.52          121.30     1068.0
# 499     91485         M        20.59         21.24          137.80     1320.0
# 500    914862         B        15.04         16.74           98.73      689.4
#
# ...

# %%
# Save DF to CSV
#df_train = df_train.to_csv("df_train_breast_cancer_prediction.csv", index=False)

# %%
#df_test = df_test.to_csv("df_test_breast_cancer_prediction.csv", index=False)
